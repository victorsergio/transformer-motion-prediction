# %%
# !pip install icecream -q
# !pip install transformers -q
# !pip install wandb -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 51.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 104.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 24.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 24.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.6 MB/s eta 0:00:00
# ...

# %%
# !python "/content/drive/Othercomputers/My Laptop/github-repositories/transformer-multi/main.py"

# %%
# !python "/content/drive/Othercomputers/My Laptop/github-repositories/transformer-multi/predict.py"
# Out:
# data X shape: (40228, 19, 3)
# data Y shape: (40228, 19, 3)
# data X shape: (40228, 8, 3)
# data Y shape: (40228, 12, 3)
# [2023-10-02 14:06:43] [INFO] __main__ Loss On Unseen Dataset: 6.425531707528668

# %%
# !rm -rf save_model/
# !rm -rf save_predictions/
# !rm scalar_item.joblib
# !rm -rf save_loss/
